# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv("Salaries.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0           1       Prof          B             19           18    Male
# 1           2       Prof          B             20           16    Male
# 2           3   AsstProf          B              4            3    Male
# 3           4       Prof          B             45           39    Male
# 4           5       Prof          B             40           41    Male
# 5           6  AssocProf          B              6            6    Male
# 6           7       Prof          B             30           23    Male
# 7           8       Prof          B             45           45    Male
# 8           9       Prof          B             21           20    Male
# 9          10       Prof          B             18           18  Female
#
#    salary
# 0  139750
# 1  173200
# 2   79750
# 3  115000
# 4  141500
# 5   97000
# 6  175000
# 7  147765
# 8  119250
# 9  129000

# %%
df.head(20)
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0            1       Prof          B             19           18    Male
# 1            2       Prof          B             20           16    Male
# 2            3   AsstProf          B              4            3    Male
# 3            4       Prof          B             45           39    Male
# 4            5       Prof          B             40           41    Male
# 5            6  AssocProf          B              6            6    Male
# 6            7       Prof          B             30           23    Male
# 7            8       Prof          B             45           45    Male
# 8            9       Prof          B             21           20    Male
# 9           10       Prof          B             18           18  Female
# 10          11  AssocProf          B             12            8    Male
# 11          12   AsstProf          B              7            2    Male
# ...

# %%
df.head(50)
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0            1       Prof          B             19           18    Male
# 1            2       Prof          B             20           16    Male
# 2            3   AsstProf          B              4            3    Male
# 3            4       Prof          B             45           39    Male
# 4            5       Prof          B             40           41    Male
# 5            6  AssocProf          B              6            6    Male
# 6            7       Prof          B             30           23    Male
# 7            8       Prof          B             45           45    Male
# 8            9       Prof          B             21           20    Male
# 9           10       Prof          B             18           18  Female
# 10          11  AssocProf          B             12            8    Male
# 11          12   AsstProf          B              7            2    Male
# ...

# %%
df['salary'].dtype
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
df.shape
# Out:
# (397, 7)

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#        'sex', 'salary'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=397, step=1),
#  Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#         'sex', 'salary'],
#        dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 2779

# %%
df.shape
# Out:
# (397, 7)

# %%
df.values
# Out:
# array([[1, 'Prof', 'B', ..., 18, 'Male', 139750],
#        [2, 'Prof', 'B', ..., 16, 'Male', 173200],
#        [3, 'AsstProf', 'B', ..., 3, 'Male', 79750],
#        ...,
#        [395, 'Prof', 'A', ..., 25, 'Male', 101738],
#        [396, 'Prof', 'A', ..., 15, 'Male', 95329],
#        [397, 'AsstProf', 'A', ..., 4, 'Male', 81035]], dtype=object)

# %%
df.max()
# Out:
# Unnamed: 0          397
# rank               Prof
# discipline            B
# yrs.since.phd        56
# yrs.service          60
# sex                Male
# salary           231545
# dtype: object

# %%
df.min()
# Out:
# Unnamed: 0               1
# rank             AssocProf
# discipline               A
# yrs.since.phd            1
# yrs.service              0
# sex                 Female
# salary               57800
# dtype: object

# %%
df.mean()
# Out:
# Unnamed: 0          199.000000
# yrs.since.phd        22.314861
# yrs.service          17.614610
# salary           113706.458438
# dtype: float64

# %%
df.median()
# Out:
# Unnamed: 0          199.0
# yrs.since.phd        21.0
# yrs.service          16.0
# salary           107300.0
# dtype: float64

# %%
df['salary'].max()
# Out:
# 231545

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].std()
# Out:
# 30289.038694747804

# %%
df['yrs.service'].median()
# Out:
# 16.0

# %%
df['yrs.service'].mean()
# Out:
# 17.614609571788414

# %%
df['yrs.service'].describe()
# Out:
# count    397.000000
# mean      17.614610
# std       13.006024
# min        0.000000
# 25%        7.000000
# 50%       16.000000
# 75%       27.000000
# max       60.000000
# Name: yrs.service, dtype: float64

# %%
df_rank = df.groupby(['rank'])

# %%
df_rank.mean()
# Out:
#            Unnamed: 0  yrs.since.phd  yrs.service         salary
# rank
# AssocProf  179.828125      15.453125    11.953125   93876.437500
# AsstProf   169.761194       5.104478     2.373134   80775.985075
# Prof       210.977444      28.300752    22.815789  126772.109023

# %%
df.sex
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
# 5        Male
# 6        Male
# 7        Male
# 8        Male
# 9      Female
# 10       Male
# 11       Male
# 12       Male
# 13       Male
# 14       Male
# 15       Male
# 16       Male
# 17       Male
# 18       Male
# 19     Female
# 20       Male
# 21       Male
# 22       Male
# 23       Male
# 24     Female
# 25       Male
# 26       Male
# 27       Male
# 28       Male
# 29       Male
#         ...
# 367      Male
# 368      Male
# 369      Male
# 370      Male
# 371      Male
# 372      Male
# 373      Male
# 374      Male
# 375      Male
# 376      Male
# 377      Male
# 378      Male
# 379      Male
# 380      Male
# 381      Male
# 382      Male
# 383      Male
# 384      Male
# 385      Male
# 386      Male
# 387      Male
# 388      Male
# 389      Male
# 390      Male
# 391      Male
# 392      Male
# 393      Male
# 394      Male
# 395      Male
# 396      Male
# ...

# %%
df.head(50).mean()
# Out:
# Unnamed: 0           25.50
# yrs.since.phd        20.92
# yrs.service          16.22
# salary           112625.64
# dtype: float64

# %%
df.head(10).mean()
# Out:
# Unnamed: 0            5.5
# yrs.since.phd        24.8
# yrs.service          22.9
# salary           131721.5
# dtype: float64

# %%
df.head(100).mean()
# Out:
# Unnamed: 0           50.50
# yrs.since.phd        19.61
# yrs.service          15.34
# salary           111479.37
# dtype: float64

# %%
df.head(60).mean()
# Out:
# Unnamed: 0           30.500000
# yrs.since.phd        19.816667
# yrs.service          15.316667
# salary           110314.450000
# dtype: float64

# %%
df['sex']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
# 5        Male
# 6        Male
# 7        Male
# 8        Male
# 9      Female
# 10       Male
# 11       Male
# 12       Male
# 13       Male
# 14       Male
# 15       Male
# 16       Male
# 17       Male
# 18       Male
# 19     Female
# 20       Male
# 21       Male
# 22       Male
# 23       Male
# 24     Female
# 25       Male
# 26       Male
# 27       Male
# 28       Male
# 29       Male
#         ...
# 367      Male
# 368      Male
# 369      Male
# 370      Male
# 371      Male
# 372      Male
# 373      Male
# 374      Male
# 375      Male
# 376      Male
# 377      Male
# 378      Male
# 379      Male
# 380      Male
# 381      Male
# 382      Male
# 383      Male
# 384      Male
# 385      Male
# 386      Male
# 387      Male
# 388      Male
# 389      Male
# 390      Male
# 391      Male
# 392      Male
# 393      Male
# 394      Male
# 395      Male
# 396      Male
# ...

# %%
df.sex
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
# 5        Male
# 6        Male
# 7        Male
# 8        Male
# 9      Female
# 10       Male
# 11       Male
# 12       Male
# 13       Male
# 14       Male
# 15       Male
# 16       Male
# 17       Male
# 18       Male
# 19     Female
# 20       Male
# 21       Male
# 22       Male
# 23       Male
# 24     Female
# 25       Male
# 26       Male
# 27       Male
# 28       Male
# 29       Male
#         ...
# 367      Male
# 368      Male
# 369      Male
# 370      Male
# 371      Male
# 372      Male
# 373      Male
# 374      Male
# 375      Male
# 376      Male
# 377      Male
# 378      Male
# 379      Male
# 380      Male
# 381      Male
# 382      Male
# 383      Male
# 384      Male
# 385      Male
# 386      Male
# 387      Male
# 388      Male
# 389      Male
# 390      Male
# 391      Male
# 392      Male
# 393      Male
# 394      Male
# 395      Male
# 396      Male
# ...

# %%
df['salary'].unique()
# Out:
# array([139750, 173200,  79750, 115000, 141500,  97000, 175000, 147765,
#        119250, 129000, 119800,  79800,  77700,  78000, 104800, 117150,
#        101000, 103450, 124750, 137000,  89565, 102580,  93904, 113068,
#         74830, 106294, 134885,  82379,  77000, 118223, 132261,  79916,
#        117256,  80225, 155750,  86373, 125196, 100938, 146500,  93418,
#        101299, 231545,  94384, 114778,  98193, 151768, 140096,  70768,
#        126621, 108875,  74692, 106639, 103760,  83900, 117704,  90215,
#        100135,  75044,  90304,  75243, 109785, 103613,  68404, 100522,
#         99418, 111512,  91412, 126320, 146856, 100131,  92391, 113398,
#         73266, 150480, 193000,  86100,  84240, 150743, 135585, 144640,
#         88825, 122960, 132825, 152708,  88400, 172272, 107008,  97032,
#        105128, 105631, 166024, 123683,  84000,  95611, 129676, 102235,
#        106689, 133217, 126933, 153303, 127512,  83850, 113543,  82099,
# ...

# %%
df['rank'].unique()
# Out:
# array(['Prof', 'AsstProf', 'AssocProf'], dtype=object)

# %%
df['salary'].mean()
# Out:
# 113706.45843828715

# %%
df_rank = df.groupby(['rank'])

# %%
df_rank.mean()
# Out:
#            Unnamed: 0  yrs.since.phd  yrs.service         salary
# rank
# AssocProf  179.828125      15.453125    11.953125   93876.437500
# AsstProf   169.761194       5.104478     2.373134   80775.985075
# Prof       210.977444      28.300752    22.815789  126772.109023

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   93876.437500
# AsstProf    80775.985075
# Prof       126772.109023

# %%
df.groupby(['rank'], sort=False)[['salary']].mean()
# Out:
#                   salary
# rank
# Prof       126772.109023
# AsstProf    80775.985075
# AssocProf   93876.437500

# %%
df_rank['yrs.service','salary'].max()
# Out:
#            yrs.service  salary
# rank
# AssocProf           53  126431
# AsstProf             6   97032
# Prof                60  231545

# %%
df_rank['yrs.service','salary'].std()
# Out:
#            yrs.service        salary
# rank
# AssocProf    10.100180  13831.699844
# AsstProf      1.495811   8174.112637
# Prof         11.590493  27718.674999

# %%
df.groupby(['rank'], sort=False)[['salary']].mean()
# Out:
#                   salary
# rank
# Prof       126772.109023
# AsstProf    80775.985075
# AssocProf   93876.437500

# %%
df_rank = df.groupby(['rank'], sort=False)

# %%
df_rank.mean()
# Out:
#            Unnamed: 0  yrs.since.phd  yrs.service         salary
# rank
# Prof       210.977444      28.300752    22.815789  126772.109023
# AsstProf   169.761194       5.104478     2.373134   80775.985075
# AssocProf  179.828125      15.453125    11.953125   93876.437500

# %%
df['salary']
# Out:
# 0      139750
# 1      173200
# 2       79750
# 3      115000
# 4      141500
# 5       97000
# 6      175000
# 7      147765
# 8      119250
# 9      129000
# 10     119800
# 11      79800
# 12      77700
# 13      78000
# 14     104800
# 15     117150
# 16     101000
# 17     103450
# 18     124750
# 19     137000
# 20      89565
# 21     102580
# 22      93904
# 23     113068
# 24      74830
# 25     106294
# 26     134885
# 27      82379
# 28      77000
# 29     118223
#         ...
# 367    108413
# 368    131950
# 369    134690
# 370     78182
# 371    110515
# 372    109707
# 373    136660
# 374    103275
# 375    103649
# 376     74856
# 377     77081
# 378    150680
# 379    104121
# 380     75996
# 381    172505
# 382     86895
# 383    105000
# 384    125192
# 385    114330
# 386    139219
# 387    109305
# 388    119450
# 389    186023
# 390    166605
# 391    151292
# 392    103106
# 393    150564
# 394    101738
# 395     95329
# 396     81035
# ...

# %%
df[['rank','salary']]
# Out:
#           rank  salary
# 0         Prof  139750
# 1         Prof  173200
# 2     AsstProf   79750
# 3         Prof  115000
# 4         Prof  141500
# 5    AssocProf   97000
# 6         Prof  175000
# 7         Prof  147765
# 8         Prof  119250
# 9         Prof  129000
# 10   AssocProf  119800
# 11    AsstProf   79800
# 12    AsstProf   77700
# 13    AsstProf   78000
# 14        Prof  104800
# 15        Prof  117150
# 16        Prof  101000
# 17        Prof  103450
# 18        Prof  124750
# 19        Prof  137000
# 20        Prof   89565
# 21        Prof  102580
# 22        Prof   93904
# 23        Prof  113068
# 24   AssocProf   74830
# 25        Prof  106294
# 26        Prof  134885
# 27    AsstProf   82379
# 28    AsstProf   77000
# 29        Prof  118223
# ..         ...     ...
# 367  AssocProf  108413
# 368       Prof  131950
# 369       Prof  134690
# 370  AssocProf   78182
# 371       Prof  110515
# 372       Prof  109707
# 373       Prof  136660
# 374       Prof  103275
# ...

# %%
df[['rank','salary']][10:20]
# Out:
#          rank  salary
# 10  AssocProf  119800
# 11   AsstProf   79800
# 12   AsstProf   77700
# 13   AsstProf   78000
# 14       Prof  104800
# 15       Prof  117150
# 16       Prof  101000
# 17       Prof  103450
# 18       Prof  124750
# 19       Prof  137000

# %%
df.groupby(['rank' , 'sex'], sort=False)[['salary']].mean()
# Out:
#                          salary
# rank      sex
# Prof      Male    127120.822581
# AsstProf  Male     81311.464286
# AssocProf Male     94869.703704
# Prof      Female  121967.611111
# AssocProf Female   88512.800000
# AsstProf  Female   78049.909091

# %%
df.groupby(['sex' , 'rank'], sort=False)[['salary']].mean()
# Out:
#                          salary
# sex    rank
# Male   Prof       127120.822581
#        AsstProf    81311.464286
#        AssocProf   94869.703704
# Female Prof       121967.611111
#        AssocProf   88512.800000
#        AsstProf    78049.909091

# %%
df.groupby(['rank' , 'sex' , 'yrs.service'], sort=False)[['salary']].mean()
# Out:
#                                      salary
# rank      sex    yrs.service
# Prof      Male   18           139324.500000
#                  16           141045.000000
# AsstProf  Male   3             79714.875000
# Prof      Male   39           111783.333333
#                  41           141500.000000
# AssocProf Male   6             99069.666667
# Prof      Male   23           121293.071429
#                  45           117432.500000
#                  20           128647.300000
#           Female 18           125980.000000
# AssocProf Male   8             92703.750000
# AsstProf  Male   2             83046.500000
#                  1             74991.555556
#                  0             83349.375000
# Prof      Male   3            133815.000000
#                  34            97920.500000
#           Female 36           137000.000000
#           Male   26           118877.166667
#                  31           126459.500000
#                  30           118359.333333
# ...

# %%
df.groupby(['sex' , 'rank' , 'yrs.service'], sort=False)[['salary']].mean()
# Out:
#                                      salary
# sex    rank      yrs.service
# Male   Prof      18           139324.500000
#                  16           141045.000000
#        AsstProf  3             79714.875000
#        Prof      39           111783.333333
#                  41           141500.000000
#        AssocProf 6             99069.666667
#        Prof      23           121293.071429
#                  45           117432.500000
#                  20           128647.300000
# Female Prof      18           125980.000000
# Male   AssocProf 8             92703.750000
#        AsstProf  2             83046.500000
#                  1             74991.555556
#                  0             83349.375000
#        Prof      3            133815.000000
#                  34            97920.500000
# Female Prof      36           137000.000000
# Male   Prof      26           118877.166667
#                  31           126459.500000
#                  30           118359.333333
# ...

# %%
df[['salary']].head()
# Out:
#    salary
# 0  139750
# 1  173200
# 2   79750
# 3  115000
# 4  141500

# %%
df[['salary']].tail()
# Out:
#      salary
# 392  103106
# 393  150564
# 394  101738
# 395   95329
# 396   81035

# %%
df_sub.loc[9:10,['salary' , 'rank']]
# Out:
#    salary  rank
# 9  129000  Prof

# %%
df.loc[10:20,['salary' , 'rank']]
# Out:
#     salary       rank
# 10  119800  AssocProf
# 11   79800   AsstProf
# 12   77700   AsstProf
# 13   78000   AsstProf
# 14  104800       Prof
# 15  117150       Prof
# 16  101000       Prof
# 17  103450       Prof
# 18  124750       Prof
# 19  137000       Prof
# 20   89565       Prof

# %%
df_sub.loc[9:10,['salary' , 'rank' , 'sex']]
# Out:
#    salary  rank     sex
# 9  129000  Prof  Female

# %%
df.loc[9:10,['salary' , 'rank' , 'sex']]
# Out:
#     salary       rank     sex
# 9   129000       Prof  Female
# 10  119800  AssocProf    Male

# %%
df_sub.iloc[10:20,[0, 3, 4, 5]]
# Out:
#     Unnamed: 0  yrs.since.phd  yrs.service     sex
# 36          37             22           21    Male
# 38          39             41           31    Male
# 40          41             23            2    Male
# 43          44             38           38    Male
# 47          48             23           19  Female
# 48          49             25           25  Female
# 50          51             28           28    Male
# 70          71             17            2    Male
# 71          72             45           45    Male
# 76          77             17            3    Male

# %%
df.iloc[-1][['salary' , 'rank' , 'sex']]
# Out:
# salary       81035
# rank      AsstProf
# sex           Male
# Name: 396, dtype: object

# %%
df.iloc[0:7][['salary' , 'rank' , 'sex']]
# Out:
#    salary       rank   sex
# 0  139750       Prof  Male
# 1  173200       Prof  Male
# 2   79750   AsstProf  Male
# 3  115000       Prof  Male
# 4  141500       Prof  Male
# 5   97000  AssocProf  Male
# 6  175000       Prof  Male

# %%
df_sorted = df.sort_values( by ='yrs.service')
df_sorted.head()
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service     sex  \
# 154         155  AsstProf          B              4            0    Male
# 127         128  AsstProf          A              2            0  Female
# 164         165  AsstProf          B              1            0    Male
# 28           29  AsstProf          B             11            0    Male
# 287         288  AsstProf          A              2            0    Male
#
#      salary
# 154   92000
# 127   72500
# 164   88795
# 28    77000
# 287   85000

# %%
df_sorted = df.sort_values( by ='rank')
df_sorted.head()
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service   sex  \
# 168         169  AssocProf          B              8            6  Male
# 60           61  AssocProf          B              9            8  Male
# 322         323  AssocProf          B             13           11  Male
# 58           59  AssocProf          B             10            9  Male
# 57           58  AssocProf          B              9            8  Male
#
#      salary
# 168  101210
# 60    90304
# 322  126431
# 58   100135
# 57    90215

# %%
df_sorted = df.sort_values( by ='salary')
df_sorted.head()
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 282         283       Prof          A             51           51    Male
# 123         124  AssocProf          A             25           22  Female
# 237         238   AsstProf          A              7            6  Female
# 226         227   AsstProf          A              3            1    Male
# 317         318       Prof          B             46           45    Male
#
#      salary
# 282   57800
# 123   62884
# 237   63100
# 226   63900
# 317   67559

# %%
df_sorted = df.sort_values( by =['yrs.service', 'salary'], ascending = [True, False])
df_sorted.head(10)
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service     sex  \
# 114         115      Prof          A             12            0  Female
# 154         155  AsstProf          B              4            0    Male
# 164         165  AsstProf          B              1            0    Male
# 157         158  AsstProf          B              1            0    Male
# 287         288  AsstProf          A              2            0    Male
# 95           96  AsstProf          B              4            0    Male
# 13           14  AsstProf          B              2            0    Male
# 28           29  AsstProf          B             11            0    Male
# 35           36  AsstProf          B              5            0  Female
# 308         309  AsstProf          A              5            0    Male
#
#      salary
# 114  105000
# 154   92000
# 164   88795
# 157   88000
# 287   85000
# 95    84000
# 13    78000
# 28    77000
# 35    77000
# 308   74000

# %%
flights = pd.read_csv("flights.csv")

# %%
flights[flights.isnull().any(axis=1)].head()
# Out:
#      Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 471         472  2013      1    1    1525.0            1530       -5.0
# 477         478  2013      1    1    1528.0            1459       29.0
# 615         616  2013      1    1    1740.0            1745       -5.0
# 643         644  2013      1    1    1807.0            1738       29.0
# 725         726  2013      1    1    1939.0            1840       59.0
#
#      arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 471    1934.0            1805        NaN      MQ    4525  N719MQ    LGA  XNA
# 477    2002.0            1647        NaN      EV    3806  N17108    EWR  STL
# 615    2158.0            2020        NaN      MQ    4413  N739MQ    LGA  XNA
# 643    2251.0            2103        NaN      UA    1228  N31412    EWR  SAN
# 725      29.0            2151        NaN      9E    3325  N905XJ    JFK  DFW
#
#      air_time  distance  hour  minute            time_hour
# ...

# %%
df_sorted = df.sort_values( by =['yrs.service', 'salary'], ascending = [True, False])
df_sorted.dropna()
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 114         115       Prof          A             12            0  Female
# 154         155   AsstProf          B              4            0    Male
# 164         165   AsstProf          B              1            0    Male
# 157         158   AsstProf          B              1            0    Male
# 287         288   AsstProf          A              2            0    Male
# 95           96   AsstProf          B              4            0    Male
# 13           14   AsstProf          B              2            0    Male
# 28           29   AsstProf          B             11            0    Male
# 35           36   AsstProf          B              5            0  Female
# 308         309   AsstProf          A              5            0    Male
# 127         128   AsstProf          A              2            0  Female
# 214         215  AssocProf          B             11            1    Male
# ...

# %%
df_sorted = df.sort_values( by =['yrs.service', 'salary'], ascending = [True, False])
df_sorted.dropna(how='all')
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 114         115       Prof          A             12            0  Female
# 154         155   AsstProf          B              4            0    Male
# 164         165   AsstProf          B              1            0    Male
# 157         158   AsstProf          B              1            0    Male
# 287         288   AsstProf          A              2            0    Male
# 95           96   AsstProf          B              4            0    Male
# 13           14   AsstProf          B              2            0    Male
# 28           29   AsstProf          B             11            0    Male
# 35           36   AsstProf          B              5            0  Female
# 308         309   AsstProf          A              5            0    Male
# 127         128   AsstProf          A              2            0  Female
# 214         215  AssocProf          B             11            1    Male
# ...

# %%
df_sorted = df.sort_values( by =['yrs.service', 'salary'], ascending = [True, False])
df_sorted.dropna(axis=1, how='all')
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 114         115       Prof          A             12            0  Female
# 154         155   AsstProf          B              4            0    Male
# 164         165   AsstProf          B              1            0    Male
# 157         158   AsstProf          B              1            0    Male
# 287         288   AsstProf          A              2            0    Male
# 95           96   AsstProf          B              4            0    Male
# 13           14   AsstProf          B              2            0    Male
# 28           29   AsstProf          B             11            0    Male
# 35           36   AsstProf          B              5            0  Female
# 308         309   AsstProf          A              5            0    Male
# 127         128   AsstProf          A              2            0  Female
# 214         215  AssocProf          B             11            1    Male
# ...

# %%
f_sorted = df.sort_values( by =['yrs.service', 'salary'], ascending = [True, False])
df_sorted.dropna(thresh = 5)
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 114         115       Prof          A             12            0  Female
# 154         155   AsstProf          B              4            0    Male
# 164         165   AsstProf          B              1            0    Male
# 157         158   AsstProf          B              1            0    Male
# 287         288   AsstProf          A              2            0    Male
# 95           96   AsstProf          B              4            0    Male
# 13           14   AsstProf          B              2            0    Male
# 28           29   AsstProf          B             11            0    Male
# 35           36   AsstProf          B              5            0  Female
# 308         309   AsstProf          A              5            0    Male
# 127         128   AsstProf          A              2            0  Female
# 214         215  AssocProf          B             11            1    Male
# ...

# %%
f_sorted = df.sort_values( by =['yrs.service', 'salary'], ascending = [True, False])
df_sorted.fillna(0)
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 114         115       Prof          A             12            0  Female
# 154         155   AsstProf          B              4            0    Male
# 164         165   AsstProf          B              1            0    Male
# 157         158   AsstProf          B              1            0    Male
# 287         288   AsstProf          A              2            0    Male
# 95           96   AsstProf          B              4            0    Male
# 13           14   AsstProf          B              2            0    Male
# 28           29   AsstProf          B             11            0    Male
# 35           36   AsstProf          B              5            0  Female
# 308         309   AsstProf          A              5            0    Male
# 127         128   AsstProf          A              2            0  Female
# 214         215  AssocProf          B             11            1    Male
# ...

# %%
f_sorted = df.sort_values( by =['yrs.service', 'salary'], ascending = [True, False])
df_sorted.isnull()
# Out:
#      Unnamed: 0   rank  discipline  yrs.since.phd  yrs.service    sex  salary
# 114       False  False       False          False        False  False   False
# 154       False  False       False          False        False  False   False
# 164       False  False       False          False        False  False   False
# 157       False  False       False          False        False  False   False
# 287       False  False       False          False        False  False   False
# 95        False  False       False          False        False  False   False
# 13        False  False       False          False        False  False   False
# 28        False  False       False          False        False  False   False
# 35        False  False       False          False        False  False   False
# 308       False  False       False          False        False  False   False
# 127       False  False       False          False        False  False   False
# ...

# %%
f_sorted = df.sort_values( by =['yrs.service', 'salary'], ascending = [True, False])
df_sorted.notnull()
# Out:
#      Unnamed: 0  rank  discipline  yrs.since.phd  yrs.service   sex  salary
# 114        True  True        True           True         True  True    True
# 154        True  True        True           True         True  True    True
# 164        True  True        True           True         True  True    True
# 157        True  True        True           True         True  True    True
# 287        True  True        True           True         True  True    True
# 95         True  True        True           True         True  True    True
# 13         True  True        True           True         True  True    True
# 28         True  True        True           True         True  True    True
# 35         True  True        True           True         True  True    True
# 308        True  True        True           True         True  True    True
# 127        True  True        True           True         True  True    True
# ...

# %%
f_sorted = df.sort_values( by =['yrs.service', 'salary'], ascending = [True, False])
df_sorted.max()
# Out:
# Unnamed: 0          397
# rank               Prof
# discipline            B
# yrs.since.phd        56
# yrs.service          60
# sex                Male
# salary           231545
# dtype: object

# %%
flights = pd.read_csv("flights.csv")

# %%
flights[flights.isnull().any(axis=1)].head()
# Out:
#      Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 471         472  2013      1    1    1525.0            1530       -5.0
# 477         478  2013      1    1    1528.0            1459       29.0
# 615         616  2013      1    1    1740.0            1745       -5.0
# 643         644  2013      1    1    1807.0            1738       29.0
# 725         726  2013      1    1    1939.0            1840       59.0
#
#      arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 471    1934.0            1805        NaN      MQ    4525  N719MQ    LGA  XNA
# 477    2002.0            1647        NaN      EV    3806  N17108    EWR  STL
# 615    2158.0            2020        NaN      MQ    4413  N739MQ    LGA  XNA
# 643    2251.0            2103        NaN      UA    1228  N31412    EWR  SAN
# 725      29.0            2151        NaN      9E    3325  N905XJ    JFK  DFW
#
#      air_time  distance  hour  minute            time_hour
# ...

# %%
flights = pd.read_csv("flights.csv")

# %%
flights[flights.isnull().any(axis=1)].max()
# Out:
# Unnamed: 0                     336776
# year                             2013
# month                              12
# day                                31
# dep_time                         2359
# sched_dep_time                   2359
# dep_delay                         634
# arr_time                         2359
# sched_arr_time                   2359
# arr_delay                         NaN
# carrier                            YV
# flight                           6177
# origin                            LGA
# dest                              XNA
# air_time                          NaN
# distance                         4963
# hour                               23
# minute                             59
# time_hour         2013-12-31 20:00:00
# dtype: object

# %%
flights = pd.read_csv("flights.csv")

# %%
flights['carrier'][flights.isnull().any(axis=1)]
# Out:
# 471       MQ
# 477       EV
# 615       MQ
# 643       UA
# 725       9E
# 733       EV
# 754       EV
# 838       EV
# 839       AA
# 840       AA
# 841       B6
# 1071      EV
# 1180      9E
# 1604      9E
# 1606      EV
# 1650      9E
# 1714      B6
# 1756      UA
# 1777      EV
# 1778      EV
# 1779      EV
# 1780      EV
# 1781      EV
# 1782      AA
# 1783      AA
# 1784      UA
# 2074      EV
# 2212      DL
# 2537      9E
# 2560      EV
#           ..
# 332193    MQ
# 332194    MQ
# 332671    UA
# 333188    EV
# 333189    US
# 333190    WN
# 333666    AA
# 334177    EV
# 334183    AA
# 334184    US
# 334185    MQ
# 334186    UA
# 334197    EV
# 334354    EV
# 334412    EV
# 334495    AA
# 334866    EV
# 334867    AA
# 334868    US
# 335534    UA
# 335780    EV
# 335781    MQ
# 335782    UA
# 335805    WN
# 336770    EV
# 336771    9E
# 336772    9E
# 336773    MQ
# 336774    MQ
# 336775    MQ
# Name: carrier, Length: 9430, dtype: object

# %%
flights['carrier'][flights.isnull().any(axis=1)].head().unique()
# Out:
# array(['MQ', 'EV', 'UA', '9E'], dtype=object)

# %%
flights[['carrier','tailnum']][flights.isnull().any(axis=1)].head()
# Out:
#     carrier tailnum
# 471      MQ  N719MQ
# 477      EV  N17108
# 615      MQ  N739MQ
# 643      UA  N31412
# 725      9E  N905XJ

# %%
flights['dep_delay','origin'][flights.isnull().any(axis=1)].head().max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('dep_delay', 'origin')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-02fce5d658aa> in <module>
# ...

# %%
flights['month'][flights.isnull().any(axis=1)].max()
# Out:
# 12

# %%
flights[['arr_delay' , 'tailnum']][flights.any(axis=1)].max()
# Out:
# arr_delay    1272.0
# dtype: float64

# %%
flights['carrier'].unique()
# Out:
# array(['UA', 'AA', 'B6', 'DL', 'EV', 'MQ', 'US', 'WN', 'VX', 'FL', 'AS',
#        '9E', 'F9', 'HA', 'YV', 'OO'], dtype=object)

# %%
flights['carrier'].tail()
# Out:
# 336771    9E
# 336772    9E
# 336773    MQ
# 336774    MQ
# 336775    MQ
# Name: carrier, dtype: object

# %%
flights[['carrier','tailnum']]
# Out:
#        carrier tailnum
# 0           UA  N14228
# 1           UA  N24211
# 2           AA  N619AA
# 3           B6  N804JB
# 4           DL  N668DN
# 5           UA  N39463
# 6           B6  N516JB
# 7           EV  N829AS
# 8           B6  N593JB
# 9           AA  N3ALAA
# 10          B6  N793JB
# 11          B6  N657JB
# 12          UA  N29129
# 13          UA  N53441
# 14          AA  N3DUAA
# 15          B6  N708JB
# 16          UA  N76515
# 17          B6  N595JB
# 18          MQ  N542MQ
# 19          B6  N644JB
# 20          DL  N971DL
# 21          MQ  N730MQ
# 22          AA  N633AA
# 23          DL  N3739P
# 24          UA  N53442
# 25          MQ  N9EAMQ
# 26          UA  N532UA
# 27          B6  N635JB
# 28          B6  N794JB
# 29          DL  N326NB
# ...        ...     ...
# 336746      EV  N712EV
# 336747      EV  N16546
# 336748      B6  N807JB
# 336749      EV  N751EV
# 336750      MQ  N807MQ
# 336751      AA  N335AA
# 336752      EV  N12957
# 336753      B6  N633JB
# ...

# %%
flights['dep_delay'].max()
# Out:
# 1301.0

# %%
flights['month'].max()
# Out:
# 12

# %%
flights['dep_delay'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('dep_delay', 'origin')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-170-10f9f3d177c0> in <module>
# ...

# %%
flights = pd.read_csv("flights.csv")

# %%
flights
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0                1  2013      1    1     517.0             515        2.0
# 1                2  2013      1    1     533.0             529        4.0
# 2                3  2013      1    1     542.0             540        2.0
# 3                4  2013      1    1     544.0             545       -1.0
# 4                5  2013      1    1     554.0             600       -6.0
# 5                6  2013      1    1     554.0             558       -4.0
# 6                7  2013      1    1     555.0             600       -5.0
# 7                8  2013      1    1     557.0             600       -3.0
# 8                9  2013      1    1     557.0             600       -3.0
# 9               10  2013      1    1     558.0             600       -2.0
# 10              11  2013      1    1     558.0             600       -2.0
# 11              12  2013      1    1     558.0             600       -2.0
# ...

# %%
flights.groupby('month')['flight'].max()
# Out:
# month
# 1     8500
# 2     6171
# 3     6180
# 4     5968
# 5     5769
# 6     6177
# 7     6177
# 8     6177
# 9     6181
# 10    6181
# 11    6181
# 12    6181
# Name: flight, dtype: int64

# %%
flights.groupby('tailnum','arr_delay')['flight'].max()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-178-f4e885d6860f> in <module>
# ----> 1 flights.groupby('tailnum','arr_delay')['flight'].max()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7627         if level is None and by is None:
#    7628             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 7629         axis = self._get_axis_number(axis)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     359                 pass
#     360         raise ValueError('No axis named {0} for object type {1}'
# ...

# %%
flights.groupby('month')['flight'].max()
# Out:
# month
# 1     8500
# 2     6171
# 3     6180
# 4     5968
# 5     5769
# 6     6177
# 7     6177
# 8     6177
# 9     6181
# 10    6181
# 11    6181
# 12    6181
# Name: flight, dtype: int64

# %%
flights['dep_delay'].mean()
# Out:
# 12.639070257304708

# %%
flights.groupby(['tailnum','arr_delay'], sort=False)[['flight']].max()
# Out:
#                    flight
# tailnum arr_delay
# N14228   11.0        1545
# N24211   20.0        1714
# N619AA   33.0        1141
# N804JB  -18.0         727
# N668DN  -25.0         461
# N39463   12.0        1696
# N516JB   19.0        1295
# N829AS  -14.0        5747
# N593JB  -8.0         1161
# N3ALAA   8.0          301
# N793JB  -2.0         1002
# N657JB  -3.0         1783
# N29129   7.0         1643
# N53441  -14.0        1124
# N3DUAA   31.0         707
# N708JB  -4.0         1806
# N76515  -8.0         1668
# N595JB  -7.0         1883
# N542MQ   12.0        4662
# N644JB  -6.0         1295
# N971DL  -8.0         1919
# N730MQ   16.0        4569
# N633AA  -12.0        1895
# N3739P  -8.0         2065
# N53442  -17.0        1485
# N9EAMQ   32.0        3768
# N532UA   14.0         512
# N635JB   4.0         1129
# N794JB  -21.0         709
# N326NB  -9.0         1715
# ...                   ...
# N905DL   1.0         2159
# N629JB  -40.0         161
# N724MQ   105.0       3526
# ...

# %%
x1 = flights['origin']

# %%
x1.groupby(['JFK','dep_delay'], sort=False)[['flight']].median()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-802bf0eb0e31> in <module>
# ----> 1 x1.groupby(['JFK','dep_delay'], sort=False)[['flight']].median()
#
# NameError: name 'x1' is not defined

# %%
flights.shape
# Out:
# (336776, 20)

# %%
flights = pd.read_csv("flights.csv")

# %%
flights.shape
# Out:
# (336776, 20)

# %%
flights['carrier'].unique()
# Out:
# array(['UA', 'AA', 'B6', 'DL', 'EV', 'MQ', 'US', 'WN', 'VX', 'FL', 'AS',
#        '9E', 'F9', 'HA', 'YV', 'OO'], dtype=object)

# %%
flights['carrier'].tail()
# Out:
# 336771    9E
# 336772    9E
# 336773    MQ
# 336774    MQ
# 336775    MQ
# Name: carrier, dtype: object

# %%
flights[['carrier','tailnum']]
# Out:
#        carrier tailnum
# 0           UA  N14228
# 1           UA  N24211
# 2           AA  N619AA
# 3           B6  N804JB
# 4           DL  N668DN
# 5           UA  N39463
# 6           B6  N516JB
# 7           EV  N829AS
# 8           B6  N593JB
# 9           AA  N3ALAA
# 10          B6  N793JB
# 11          B6  N657JB
# 12          UA  N29129
# 13          UA  N53441
# 14          AA  N3DUAA
# 15          B6  N708JB
# 16          UA  N76515
# 17          B6  N595JB
# 18          MQ  N542MQ
# 19          B6  N644JB
# 20          DL  N971DL
# 21          MQ  N730MQ
# 22          AA  N633AA
# 23          DL  N3739P
# 24          UA  N53442
# 25          MQ  N9EAMQ
# 26          UA  N532UA
# 27          B6  N635JB
# 28          B6  N794JB
# 29          DL  N326NB
# ...        ...     ...
# 336746      EV  N712EV
# 336747      EV  N16546
# 336748      B6  N807JB
# 336749      EV  N751EV
# 336750      MQ  N807MQ
# 336751      AA  N335AA
# 336752      EV  N12957
# 336753      B6  N633JB
# ...

# %%
flights['dep_delay'].max()
# Out:
# 1301.0

# %%
flights.groupby('month')['flight'].max()
# Out:
# month
# 1     8500
# 2     6171
# 3     6180
# 4     5968
# 5     5769
# 6     6177
# 7     6177
# 8     6177
# 9     6181
# 10    6181
# 11    6181
# 12    6181
# Name: flight, dtype: int64

# %%
flights.groupby(['tailnum','arr_delay'], sort=False)[['flight']].median()
# Out:
#                    flight
# tailnum arr_delay
# N14228   11.0      1407.0
# N24211   20.0      1601.0
# N619AA   33.0      1141.0
# N804JB  -18.0       512.0
# N668DN  -25.0       461.0
# N39463   12.0      1696.0
# N516JB   19.0       983.0
# N829AS  -14.0      5713.5
# N593JB  -8.0        389.0
# N3ALAA   8.0        301.0
# N793JB  -2.0        645.0
# N657JB  -3.0        474.0
# N29129   7.0        918.5
# N53441  -14.0      1119.5
# N3DUAA   31.0       707.0
# N708JB  -4.0       1266.5
# N76515  -8.0       1187.0
# N595JB  -7.0        653.0
# N542MQ   12.0      4650.0
# N644JB  -6.0        713.0
# N971DL  -8.0       1847.0
# N730MQ   16.0      4485.0
# N633AA  -12.0      1895.0
# N3739P  -8.0       1773.0
# N53442  -17.0      1281.0
# N9EAMQ   32.0      3768.0
# N532UA   14.0       407.5
# N635JB   4.0        411.0
# N794JB  -21.0       371.0
# N326NB  -9.0       1081.0
# ...                   ...
# N905DL   1.0       2159.0
# N629JB  -40.0       161.0
# N724MQ   105.0     3526.0
# ...

# %%
flights.groupby(['tailnum','arr_delay'], sort=False)[['flight']].mean()
# Out:
#                         flight
# tailnum arr_delay
# N14228   11.0      1407.000000
# N24211   20.0      1509.000000
# N619AA   33.0      1141.000000
# N804JB  -18.0       453.500000
# N668DN  -25.0       461.000000
# N39463   12.0      1696.000000
# N516JB   19.0       770.142857
# N829AS  -14.0      5721.500000
# N593JB  -8.0        472.571429
# N3ALAA   8.0        301.000000
# N793JB  -2.0        604.400000
# N657JB  -3.0        628.000000
# N29129   7.0        918.500000
# N53441  -14.0      1119.500000
# N3DUAA   31.0       707.000000
# N708JB  -4.0       1266.500000
# N76515  -8.0       1307.000000
# N595JB  -7.0        828.333333
# N542MQ   12.0      4328.666667
# N644JB  -6.0        664.222222
# N971DL  -8.0       1532.333333
# N730MQ   16.0      4485.000000
# N633AA  -12.0      1895.000000
# N3739P  -8.0       1860.333333
# N53442  -17.0      1281.000000
# N9EAMQ   32.0      3768.000000
# N532UA   14.0       407.500000
# N635JB   4.0        450.000000
# ...

# %%
flights.groupby(['tailnum','arr_delay'], sort=False)[['flight']].max()
# Out:
#                    flight
# tailnum arr_delay
# N14228   11.0        1545
# N24211   20.0        1714
# N619AA   33.0        1141
# N804JB  -18.0         727
# N668DN  -25.0         461
# N39463   12.0        1696
# N516JB   19.0        1295
# N829AS  -14.0        5747
# N593JB  -8.0         1161
# N3ALAA   8.0          301
# N793JB  -2.0         1002
# N657JB  -3.0         1783
# N29129   7.0         1643
# N53441  -14.0        1124
# N3DUAA   31.0         707
# N708JB  -4.0         1806
# N76515  -8.0         1668
# N595JB  -7.0         1883
# N542MQ   12.0        4662
# N644JB  -6.0         1295
# N971DL  -8.0         1919
# N730MQ   16.0        4569
# N633AA  -12.0        1895
# N3739P  -8.0         2065
# N53442  -17.0        1485
# N9EAMQ   32.0        3768
# N532UA   14.0         512
# N635JB   4.0         1129
# N794JB  -21.0         709
# N326NB  -9.0         1715
# ...                   ...
# N905DL   1.0         2159
# N629JB  -40.0         161
# N724MQ   105.0       3526
# ...

# %%
flights.groupby(['tailnum','arr_delay'], sort=False)[['flight']].mean()
# Out:
#                         flight
# tailnum arr_delay
# N14228   11.0      1407.000000
# N24211   20.0      1509.000000
# N619AA   33.0      1141.000000
# N804JB  -18.0       453.500000
# N668DN  -25.0       461.000000
# N39463   12.0      1696.000000
# N516JB   19.0       770.142857
# N829AS  -14.0      5721.500000
# N593JB  -8.0        472.571429
# N3ALAA   8.0        301.000000
# N793JB  -2.0        604.400000
# N657JB  -3.0        628.000000
# N29129   7.0        918.500000
# N53441  -14.0      1119.500000
# N3DUAA   31.0       707.000000
# N708JB  -4.0       1266.500000
# N76515  -8.0       1307.000000
# N595JB  -7.0        828.333333
# N542MQ   12.0      4328.666667
# N644JB  -6.0        664.222222
# N971DL  -8.0       1532.333333
# N730MQ   16.0      4485.000000
# N633AA  -12.0      1895.000000
# N3739P  -8.0       1860.333333
# N53442  -17.0      1281.000000
# N9EAMQ   32.0      3768.000000
# N532UA   14.0       407.500000
# N635JB   4.0        450.000000
# ...

# %%
flights_f = flights[flights['origin']=='JFK']
flights_f
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 2                3  2013      1    1     542.0             540        2.0
# 3                4  2013      1    1     544.0             545       -1.0
# 8                9  2013      1    1     557.0             600       -3.0
# 10              11  2013      1    1     558.0             600       -2.0
# 11              12  2013      1    1     558.0             600       -2.0
# 12              13  2013      1    1     558.0             600       -2.0
# 15              16  2013      1    1     559.0             559        0.0
# 23              24  2013      1    1     606.0             610       -4.0
# 26              27  2013      1    1     611.0             600       11.0
# 27              28  2013      1    1     613.0             610        3.0
# 28              29  2013      1    1     615.0             615        0.0
# 35              36  2013      1    1     627.0             630       -3.0
# ...

# %%
flights_f['dep_delay'].mean()
# Out:
# 12.112159099217665

# %%
flights.groupby(['tailnum','arr_delay'], sort=False)[['flight']].max().mean()
# Out:
# flight    2030.99736
# dtype: float64

# %%
flights.groupby(['tailnum','arr_delay'], sort=False)[['flight']].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4d056b0cdf77> in <module>
# ----> 1 flights.groupby(['tailnum','arr_delay'], sort=False)[['flight']].mean()
#
# NameError: name 'flights' is not defined

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
flights = pd.read_csv("flights.csv")

# %%
flights.shape
# Out:
# (336776, 20)

# %%
f1 = flights[flights['month'] == 1]

# %%
f1.shape
# Out:
# (27004, 20)

# %%
f1 = flights[(flights['month'] == 1) | (flights['month'] == 4)]

# %%
f1.shape
# Out:
# (55334, 20)

# %%
flights[(flights['month'] == 1) | (flights['origin']=='JFK')]
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0                1  2013      1    1     517.0             515        2.0
# 1                2  2013      1    1     533.0             529        4.0
# 2                3  2013      1    1     542.0             540        2.0
# 3                4  2013      1    1     544.0             545       -1.0
# 4                5  2013      1    1     554.0             600       -6.0
# 5                6  2013      1    1     554.0             558       -4.0
# 6                7  2013      1    1     555.0             600       -5.0
# 7                8  2013      1    1     557.0             600       -3.0
# 8                9  2013      1    1     557.0             600       -3.0
# 9               10  2013      1    1     558.0             600       -2.0
# 10              11  2013      1    1     558.0             600       -2.0
# 11              12  2013      1    1     558.0             600       -2.0
# ...

# %%
flights[(flights['month'] == 2) | (flights['month']== 3) | (flights['month']== 4) | (flights['month']== 5) | (flights['month']== 6) | (flights['month']== 7) | (flights['month']== 8) | (flights['month']== 9) | (flights['month']== 10) | (flights['month']== 11) | (flights['month']== 12)]
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 27004        27005  2013     10    1     447.0             500      -13.0
# 27005        27006  2013     10    1     522.0             517        5.0
# 27006        27007  2013     10    1     536.0             545       -9.0
# 27007        27008  2013     10    1     539.0             545       -6.0
# 27008        27009  2013     10    1     539.0             545       -6.0
# 27009        27010  2013     10    1     544.0             550       -6.0
# 27010        27011  2013     10    1     549.0             600      -11.0
# 27011        27012  2013     10    1     550.0             600      -10.0
# 27012        27013  2013     10    1     550.0             600      -10.0
# 27013        27014  2013     10    1     551.0             600       -9.0
# 27014        27015  2013     10    1     551.0             600       -9.0
# 27015        27016  2013     10    1     551.0             600       -9.0
# ...

# %%
flights[(flights['month'] == 2) | (flights['month']== 3) | (flights['month']== 4) | (flights['month']== 5) | (flights['month']== 6) | (flights['month']== 7) | (flights['month']== 8) | (flights['month']== 9) | (flights['month']== 10) | (flights['month']== 11) | (flights['month']== 12) | (flights['origin']== "JFK")]
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 2                3  2013      1    1     542.0             540        2.0
# 3                4  2013      1    1     544.0             545       -1.0
# 8                9  2013      1    1     557.0             600       -3.0
# 10              11  2013      1    1     558.0             600       -2.0
# 11              12  2013      1    1     558.0             600       -2.0
# 12              13  2013      1    1     558.0             600       -2.0
# 15              16  2013      1    1     559.0             559        0.0
# 23              24  2013      1    1     606.0             610       -4.0
# 26              27  2013      1    1     611.0             600       11.0
# 27              28  2013      1    1     613.0             610        3.0
# 28              29  2013      1    1     615.0             615        0.0
# 35              36  2013      1    1     627.0             630       -3.0
# ...

# %%
f2 = flights[(flights['month'] == 1) & (flights['origin']== "JFK") & (flights['dep_delay'] <= 0.0)]

# %%
f2 [['tailnum', 'origin' , 'dep_delay']]
# Out:
#       tailnum origin  dep_delay
# 3      N804JB    JFK       -1.0
# 8      N593JB    JFK       -3.0
# 10     N793JB    JFK       -2.0
# 11     N657JB    JFK       -2.0
# 12     N29129    JFK       -2.0
# 15     N708JB    JFK        0.0
# 23     N3739P    JFK       -4.0
# 28     N794JB    JFK        0.0
# 35     N535UW    JFK       -3.0
# 36     N3BAAA    JFK       -2.0
# 44     N805JB    JFK       -1.0
# 48     N796JB    JFK       -2.0
# 51     N558JB    JFK       -4.0
# 52     N178JB    JFK       -3.0
# 54     N3763D    JFK        0.0
# 55     N705TW    JFK       -5.0
# 58     N5FMAA    JFK       -3.0
# 63     N627VA    JFK       -2.0
# 65     N646JB    JFK       -1.0
# 71     N651JB    JFK       -4.0
# 72     N3ETAA    JFK       -3.0
# 75     N562JB    JFK       -2.0
# 82     N635VA    JFK       -1.0
# 83     N304JB    JFK       -3.0
# 86     N552JB    JFK       -3.0
# 87     N625JB    JFK       -3.0
# 92     N624JB    JFK       -6.0
# 94     N336AA    JFK        0.0
# ...

# %%
f2 = flights[(flights['carrier']== "US")]['tailnum'].unique()
len(f2)
# Out:
# 290

# %%
f2 = flights[(flights['month'] == 1) & (flights['tailnum'])]

# %%
f2 [['dep_delay' , 'flight']].max()
# Out:
# dep_delay    1301.0
# flight       8500.0
# dtype: float64

# %%
flights.nlargest(1,columns='dep_delay')[['tailnum' , 'flight' , 'dep_delay']]
# Out:
#      tailnum  flight  dep_delay
# 7072  N384HA      51     1301.0

# %%
f1 = flights[(flights['month'] == 1)]

# %%
f1.nlargest(1,columns='dep_delay')[['tailnum' , 'flight' , 'dep_delay']]
# Out:
#      tailnum  flight  dep_delay
# 7072  N384HA      51     1301.0

# %%
flights[(flights['flight']== 1545) & (flights['dep_delay'] > 0.0)][['day' , 'month' , 'dep_delay']].sort_values(by = 'dep_delay', ascending=False )
# Out:
#         day  month  dep_delay
# 213927   23      5      334.0
# 200775    8      5      203.0
# 188735   25      4      164.0
# 183028   19      4      122.0
# 33411     7     10      115.0
# 182061   18      4       96.0
# 293445   15      8       94.0
# 186694   23      4       83.0
# 207248   15      5       77.0
# 215715   24      5       74.0
# 206296   14      5       55.0
# 208223   16      5       51.0
# 181056   17      4       47.0
# 209201   17      5       44.0
# 201692    9      5       40.0
# 210811   19      5       32.0
# 134820   27      2       30.0
# 249054   29      6       29.0
# 218680   28      5       28.0
# 219081   28      5       28.0
# 212774   21      5       26.0
# 39949    14     10       24.0
# 194205    1      5       17.0
# 205276   13      5       17.0
# 195177    2      5       16.0
# 189799   27      4       16.0
# 46452    21     10       15.0
# 196131    3      5       14.0
# 217228   26      5       11.0
# 96079    15     12        9.0
# ...

# %%
flights[(flights['carrier'] != 'US') & (flights['carrier'] != 'UA') & (flights['carrier'] != 'DL') & (flights['carrier'] != 'BG')][['origin' , 'dest' , 'carrier']]
# Out:
#        origin dest carrier
# 2         JFK  MIA      AA
# 3         JFK  BQN      B6
# 6         EWR  FLL      B6
# 7         LGA  IAD      EV
# 8         JFK  MCO      B6
# 9         LGA  ORD      AA
# 10        JFK  PBI      B6
# 11        JFK  TPA      B6
# 14        LGA  DFW      AA
# 15        JFK  BOS      B6
# 17        LGA  FLL      B6
# 18        LGA  ATL      MQ
# 19        EWR  PBI      B6
# 21        LGA  DTW      MQ
# 22        EWR  MIA      AA
# 25        EWR  ORD      MQ
# 27        JFK  RSW      B6
# 28        JFK  SJU      B6
# 31        LGA  MIA      AA
# 33        EWR  MSP      EV
# 34        LGA  MSP      MQ
# 36        JFK  SJU      AA
# 38        LGA  ORD      AA
# 39        LGA  BWI      WN
# 41        EWR  IAD      EV
# 42        LGA  DFW      AA
# 43        LGA  MCO      B6
# 44        JFK  BOS      B6
# 48        JFK  BUF      B6
# 51        JFK  LAS      B6
# ...       ...  ...     ...
# 336743    JFK  JAX      B6
# 336745    EWR  DCA      EV
# ...

# %%
flights.groupby(flights['month'])['flight'].count()
# Out:
# month
# 1     27004
# 2     24951
# 3     28834
# 4     28330
# 5     28796
# 6     28243
# 7     29425
# 8     29327
# 9     27574
# 10    28889
# 11    27268
# 12    28135
# Name: flight, dtype: int64

# %%
flights.groupby(flights['month'])['flight' , 'carrier'].count()
# Out:
#        flight  carrier
# month
# 1       27004    27004
# 2       24951    24951
# 3       28834    28834
# 4       28330    28330
# 5       28796    28796
# 6       28243    28243
# 7       29425    29425
# 8       29327    29327
# 9       27574    27574
# 10      28889    28889
# 11      27268    27268
# 12      28135    28135

# %%
flights.groupby(['month' , 'carrier']).filter(lambda g: len(g) > 2000).groupby(['month' , 'carrier']).size()
# Out:
# month  carrier
# 1      AA         2794
#        B6         4427
#        DL         3690
#        EV         4171
#        MQ         2271
#        UA         4637
# 2      AA         2517
#        B6         4103
#        DL         3444
#        EV         3827
#        MQ         2044
#        UA         4346
# 3      AA         2787
#        B6         4772
#        DL         4189
#        EV         4726
#        MQ         2256
#        UA         4971
# 4      AA         2722
#        B6         4517
#        DL         4092
#        EV         4561
#        MQ         2211
#        UA         5047
# 5      AA         2803
#        B6         4576
#        DL         4082
#        EV         4817
#        MQ         2284
#        UA         4960
#                   ...
# 8      AA         2856
#        B6         4952
#        DL         4318
#        EV         4563
#        MQ         2263
#        UA         5124
# 9      AA         2614
#        B6         4291
# ...

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.arange(10)
plt.plot(data)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randn(50).cumsum(), 'k--')
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
iris = pd.read_csv('iris.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
print (iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# class           150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris = pd.read_csv('iris.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
print (iris.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
wine_reviews = pd.read_csv('wine.csv', index_col=0)
wine_reviews.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(iris['sepal_length'], iris['sepal_width'])
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
colors = {'Iris-setosa':'r','Iris-versicolor':'g','Iris-virginica':'b'}
fig,ax = plt.subplots()
    for i in range(len(iris['sepal_length'])):
        ax.scatter(iris['sepal_length'][i],iris['sepal_width'][i],color=colors[iris['class'][i]])
        ax.set_title('Iris Dataset')
        ax.set_xlabel('sepal_length')
        ax.set_ylabel('sepal_width')
# Out:
#   File "<ipython-input-115-48adb918ff5a>", line 3
#     for i in range(len(iris['sepal_length'])):
#     ^
# IndentationError: unexpected indent

# %%
columns = iris.columns.drop(['class'])
x_data = range(0, iris.shape[0])
fig, ax = plt.subplots()
for column in columns:
    ax.plot(x_data,iris[column])
    ax.set_title('Iris Dataset')
    ax.legend()

# %%
columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
fig, ax = plt.subplots()
data = wine_reviews['points'].value_counts()
points = data.index
frequency = data.values
ax.hist(wine_reviews.points)
ax.set_title('Wine Review Scores')
ax.set_xlabel('points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fig, ax=plt.subplots()
data=wine_reviews['points'].value_counts()
points=data.index
frequency=data.values
ax.bar(points, frequency)
ax.set_title('Wine Review Scores')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("wine.csv", index_col=0)
df.points.plot.hist()
plt.show()

# %%
linedata = iris.drop(['class'], axis=1)
linedata.plot.hist(subplots=True, layout = (2,2), figsize = (10,10), bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001705BA20>,
# ...
#       dtype=object)

# %%
linedata = iris.drop(['class'], axis=1)
linedata.plot.line(title='Iris Dataset')
plt.show()

# %%
df.points.value_counts().sort_index().plot.bar()
plt.show(block=False)

# %%
df.points.value_counts().sort_index().plot.barh()
plt.show(block=False)

# %%
import seaborn as sns

# %%
sns.scatterplot(iris.sepal_width, iris.sepal_length)

# %%
sns.distplot(iris.sepal_length, hist=False)

# %%
sns.regplot(x='sepal_length', y='sepal_width', data=iris)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
#read iris dataset
iris = pd.read_csv('iris.csv', names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])

# %%
pd.isnull((df).head())
# Out:
#    country  description  designation  points  price  province  region_1  \
# 0    False        False        False   False  False     False     False
# 1    False        False        False   False  False     False     False
# 2    False        False        False   False  False     False     False
# 3    False        False        False   False  False     False     False
# 4    False        False        False   False  False     False     False
#
#    region_2  variety  winery
# 0     False    False   False
# 1      True    False   False
# 2     False    False   False
# 3     False    False   False
# 4      True    False   False

# %%
pd.isnull(df)
# Out:
#         country  description  designation  points  price  province  region_1  \
# 0         False        False        False   False  False     False     False
# 1         False        False        False   False  False     False     False
# 2         False        False        False   False  False     False     False
# 3         False        False        False   False  False     False     False
# 4         False        False        False   False  False     False     False
# 5         False        False        False   False  False     False     False
# 6         False        False        False   False  False     False     False
# 7         False        False        False   False  False     False     False
# 8         False        False        False   False  False     False     False
# 9         False        False        False   False  False     False     False
# 10        False        False        False   False  False     False     False
# ...

# %%
pd.isnull(df.region_1).sum()
# Out:
# 25060

# %%
df[pd.isnull(df.country)]
# Out:
#        country                                        description  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %%
data.drop(columns="country")
df[pd.isnull(df.country)]
# Out:
# 87     20747
# 88     17871
# 90     15973
# 86     15573
# 89     12921
# 85     12411
# 84     10708
# 91     10536
# 92      9241
# 83      6048
# 93      6017
# 82      4041
# 94      3462
# 95      1716
# 81      1502
# 80       898
# 96       695
# 97       365
# 98       131
# 99        50
# 100       24
# Name: points, dtype: int64

# %%
wine_reviews = pd.read_csv('wine.csv', index_col=0)

# %%
fig, ax = plt_subplots()
data = wine_reviews['points'].value_counts()
points = data.index
price = data.values
ax.hist(wine_review.points)
ax.set_title('Wine Review Scores')
ax.set_xlabel('points')
ax.set_ylabel('price')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-155-5af171407c21> in <module>
# ----> 1 fig, ax = plt_subplots()
#       2 data = wine_reviews['points'].value_counts()
#       3 points = data.index
#       4 price = data.values
#       5 ax.hist(wine_review.points)
#
# NameError: name 'plt_subplots' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
wine = pd.read_csv('wine.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])

# %%
print(wine.head())
# Out:
#                                                                                                                          sepal_length  \
# NaN      country description                                        designation                          points price        province
# 0.0      US      This tremendous 100% varietal wine hails from O... Martha's Vineyard                    96     235.0      California
# 1.0      Spain   Ripe aromas of fig, blackberry and cassis are s... Carodorum Selección Especial Reserva 96     110.0  Northern Spain
# 2.0      US      Mac Watson honors the memory of a wine once mad... Special Selected Late Harvest        96     90.0       California
# 3.0      US      This spent 20 months in 30% new French oak, and... Reserve                              96     65.0           Oregon
#
#                                                                                                                              sepal_width  \
# ...

# %%
wine.describe()
# Out:
#        sepal_length  sepal_width   petal_length petal_width            class
# count        150926       125871          60954      150931           150931
# unique          456         1237             19         633            14811
# top      California  Napa Valley  Central Coast  Chardonnay  Williams Selyem
# freq          44508         6209          13057       14482              374

# %%
wine_reviews = pd.read_csv('wine.csv', index_col=0)
wine_reviews.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
wine_reviews = pd.read_csv('wine.csv', index_col=0)

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 150931 entries, (nan, country, description, designation, points, price) to (150929.0, Italy, More Pinot Grigios should taste like this. A rich pear-like nose is followed by crisp acidity, a medium body and a viscous mouthfeel. The finish is long and redolent of pears and citrus. And all for $15!, nan, 90, 15.0)
# Data columns (total 5 columns):
# sepal_length    150926 non-null object
# sepal_width     125871 non-null object
# petal_length    60954 non-null object
# petal_width     150931 non-null object
# class           150931 non-null object
# dtypes: object(5)
# memory usage: 9.9+ MB

# %%
fig, ax = plt.subplots()
data = wine_reviews['points'].value_counts()
points = data.index
frequency = data.values
ax.hist(wine_reviews.points)
ax.set_title('Wine Review Scores')
ax.set_xlabel('points')
ax.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
wine_reviews=pd.read_csv('wine.csv', index_col=0)
wine_reviews.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
fig, ax = plt.subplots()
country = ['California', 'Napa Valley', 'Central Coast', 'Chardonnay']
data = wine_reviews['points'].value_counts()
points = data.index
frequency = data.values
ax.hist([wine_reviews.points , wine_reviews.points, wine_reviews.points, wine_reviews.points], color=['orange', 'green', 'blue' , 'red'])
ax.set_title('Wine Review Scores')
ax.set_xlabel('points')
ax.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
fig, ax = plt.subplots()
country = ['California', 'Napa Valley', 'Central Coast', 'Chardonnay']
data = wine_reviews['price'].value_counts()
points = data.index
price = data.values
ax.hist([wine_reviews.points , wine_reviews.points, wine_reviews.points, wine_reviews.points], color=['orange', 'green', 'blue' , 'red'])
ax.set_title('Wine Review Scores')
ax.set_xlabel('points')
ax.set_ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
wine.describe()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [raw]
# pd.read_csv("wine.csv", index_col=0)

# %%
wine = pd.read_csv('wine.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
print(wine.describe())
# Out:
#        sepal_length  sepal_width   petal_length petal_width            class
# count        150926       125871          60954      150931           150931
# unique          456         1237             19         633            14811
# top      California  Napa Valley  Central Coast  Chardonnay  Williams Selyem
# freq          44508         6209          13057       14482              374

# %%
fig, ax = plt.subplots()
ax.scatter(wine['sepal_length'], ['sepal_width'])
ax.set_title('wine dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-fd205055d90c> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.scatter(wine['sepal_length'], ['sepal_width'])
#       3 ax.set_title('wine dataset')
#       4 ax.set_xlabel('sepal_length')
#       5 ax.set_ylabel('sepal_width')
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4170             edgecolors = 'face'
# ...

# %%
columns = wine.columns.drop(['class'])
x_data = range(0, wine.shape[0])
fig, ax = plt.subplots()
for column in columns:
    ax.plot(x_data,wine[column])
    ax.set_title('Wine Dataset')
    ax.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-289a4f92d7c4> in <module>
#       3 fig, ax = plt.subplots()
#       4 for column in columns:
# ----> 5     ax.plot(x_data,wine[column])
#       6     ax.set_title('Wine Dataset')
#       7     ax.legend()
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# ...

# %%
wine.describe()

# %%
df = pd.DataFrame('wine.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-b0d0e2737d3f> in <module>
# ----> 1 df = pd.DataFrame('wine.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466                                    dtype=values.dtype, copy=False)
#     467             else:
# --> 468                 raise ValueError('DataFrame constructor not properly called!')
#     469
#     470         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
df.plot(kind='scatter', x='sepal_length', y='sepal_width, color='red')
        plt.show()
# Out:
#   File "<ipython-input-20-6bca753724fa>", line 1
#     df.plot(kind='scatter', x='sepal_length', y='sepal_width, color='red')
#                                                                        ^
# SyntaxError: invalid syntax

# %%
wine = pd.read_csv('wine.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
print(wine.describe())
# Out:
#        sepal_length  sepal_width   petal_length petal_width            class
# count        150926       125871          60954      150931           150931
# unique          456         1237             19         633            14811
# top      California  Napa Valley  Central Coast  Chardonnay  Williams Selyem
# freq          44508         6209          13057       14482              374

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
#read wine dataset
wine = pd.read_csv('wine.csv', names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])

# %%
pd.isnull(wine)
# Out:
#                                                                                                                            sepal_length  \
# NaN      country     description                                        designation                          points price         False
# 0.0      US          This tremendous 100% varietal wine hails from O... Martha's Vineyard                    96     235.0         False
# 1.0      Spain       Ripe aromas of fig, blackberry and cassis are s... Carodorum Selección Especial Reserva 96     110.0         False
# 2.0      US          Mac Watson honors the memory of a wine once mad... Special Selected Late Harvest        96     90.0          False
# 3.0      US          This spent 20 months in 30% new French oak, and... Reserve                              96     65.0          False
# 4.0      France      This is the top wine from La Bégude, named afte... La Brûlade                           95     66.0          False
# ...

# %%
pd.isnull(wine.sepal_length).sum()
# Out:
# 5

# %%
wine = pd.read_csv("wine.csv", index_col=0)
wine[pd.isnull(wine.country)]
# Out:
#        country                                        description  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
sns.scatterplot(wine.sepal_width, wine.sepal_length)

# %%
sns.scatterplot(wine.petal_width, wine.petal_length)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
wine = pd.read_csv('wine.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure()
ax = plt.axes()
wine_reviews = pd.read_csv('wine.csv',index_col=0)
data = wine_reviews['price'].value_counts()
points = data.index
price = data.values
ax.plot(points, price);
ax.set_title('Wine Review Scores')
ax.set_xlabel('points')
ax.set_ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
wine = pd.read_csv("wine.csv", index_col=0)
BL = wine[pd.isnull(wine.country)]
df = pd.Dataframe(BL)
df.dropna(axis='columns')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-46e2ff41d88a> in <module>
#       1 wine = pd.read_csv("wine.csv", index_col=0)
#       2 BL = wine[pd.isnull(wine.country)]
# ----> 3 df = pd.Dataframe(BL)
#       4 df.dropna(axis='columns')
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
wine = pd.read_csv("wine.csv", index_col=0)
BL = wine[pd.isnull(wine.country)]
BL.dropna(axis='columns')
# Out:
#                                               description   designation  \
# 1133    Delicate white flowers and a spin of lemon pee...     Askitikos
# 1440    A blend of 60% Syrah, 30% Cabernet Sauvignon a...          Shah
# 68226   From first sniff to last, the nose never makes...  Piedra Feliz
# 113016  From first sniff to last, the nose never makes...  Piedra Feliz
# 135696  From first sniff to last, the nose never makes...  Piedra Feliz
#
#         points  price     variety     winery
# 1133        90   17.0   Assyrtiko   Tsililis
# 1440        90   30.0   Red Blend  Büyülübağ
# 68226       81   15.0  Pinot Noir    Chilcas
# 113016      81   15.0  Pinot Noir    Chilcas
# 135696      81   15.0  Pinot Noir    Chilcas
